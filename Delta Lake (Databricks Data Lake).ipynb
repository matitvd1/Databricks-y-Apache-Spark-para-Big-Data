# %% [markdown]
# # SETUP

# %%
import random
from datetime import datetime
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
db_name = "deltadb"

spark.sql(f"CREATE DATABASE IF NOT EXISTS {db_name}")
spark.sql(f"USE DATABASE {db_name}")
# Out:
# Out[2]: DataFrame[]

# %%
# Disable format check
spark.sql("SET spark.databricks.delta.formatCheck.enabled = false")
# Optimize writing
spark.sql("SET spark.databricks.delta.properties.defaults.autoOptimize.optimizeWrite = true")
# Out:
# Out[4]: DataFrame[key: string, value: string]

# %%
def my_checkpoint_dir(): 
     return "/tmp/delta_demo/chkpt/%s" % str(random.randint(0, 10000))

# User-defined function to generate random state
@udf(returnType=StringType())
def random_state():
    return str(random.choice(["CA", "TX", "NY", "WA"]))


# Function to start a streaming query with a stream of randomly generated load data and append to the parquet table
def generate_and_append_data_stream(table_format, table_name, schema_ok=False, type="batch"):
  
    stream_data = (spark.readStream.format("rate").option("rowsPerSecond", 500).load()
                        .withColumn("loan_id", 10000 + col("value"))
                        .withColumn("funded_amnt", (rand() * 5000 + 5000).cast("integer"))
                        .withColumn("paid_amnt", col("funded_amnt") - (rand() * 2000))
                        .withColumn("addr_state", random_state())
                        .withColumn("type", lit(type)))

    if schema_ok:
        stream_data = stream_data.select("loan_id", "funded_amnt", "paid_amnt", "addr_state", "type", "timestamp")
      
    query = (stream_data.writeStream
                        .format(table_format)
                        .option("checkpointLocation", my_checkpoint_dir())
                        .trigger(processingTime = "5 seconds")
                        .table(table_name))

    return query

# %%
# Function to stop all streaming queries 
def stop_all_streams():
    print("Stopping all streams")
    for s in spark.streams.active:
        try:
            s.stop()
        except:
            pass
    print("Stopped all streams")
    dbutils.fs.rm("/tmp/delta_demo/chkpt/", True)


def cleanup_paths_and_tables():
    dbutils.fs.rm("/tmp/delta_demo/", True)
    dbutils.fs.rm("file:/dbfs/tmp/delta_demo/loans_parquet/", True)
        
    for table in ["deltadb.loans_parquet", "deltadb.loans_delta", "deltadb.loans_delta2"]:
        spark.sql(f"DROP TABLE IF EXISTS {table}")
    
cleanup_paths_and_tables()

# %%
# %sh mkdir -p /dbfs/tmp/delta_demo/loans_parquet/; wget -O /dbfs/tmp/delta_demo/loans_parquet/loans.parquet https://pages.databricks.com/rs/094-YMS-629/images/SAISEU19-loan-risks.snappy.parquet
# Out:
# --2022-09-04 23:23:40--  https://pages.databricks.com/rs/094-YMS-629/images/SAISEU19-loan-risks.snappy.parquet
# Resolving pages.databricks.com (pages.databricks.com)... 104.17.70.206, 104.17.71.206, 104.17.72.206, ...
# Connecting to pages.databricks.com (pages.databricks.com)|104.17.70.206|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 164631 (161K) [text/plain]
# Saving to: ‘/dbfs/tmp/delta_demo/loans_parquet/loans.parquet’
#
#      0K .......... .......... .......... .......... .......... 31% 4.79M 0s
#     50K .......... .......... .......... .......... .......... 62% 2.80M 0s
#    100K .......... .......... .......... .......... .......... 93% 9.90M 0s
#    150K ..........                                            100% 11.9M=0.03s
#
# 2022-09-04 23:23:41 (4.69 MB/s) - ‘/dbfs/tmp/delta_demo/loans_parquet/loans.parquet’ saved [164631/164631]

# %%
# Batch data
parquet_path = "file:/dbfs/tmp/delta_demo/loans_parquet/"

# Read parquet file downloaded from https://pages.databricks.com/rs/094-YMS-629/images/SAISEU19-loan-risks.snappy.parquet
df = (spark.read.format("parquet").load(parquet_path)
                .withColumn("type", lit("batch"))
                .withColumn("timestamp", current_timestamp()))

# Save spark dataframe as Delta table in dbfs
df.write.format("delta").mode("overwrite").saveAsTable("loans_delta")

# %%
# %fs ls file:/dbfs/tmp/delta_demo/loans_parquet/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>file:/dbfs/tmp/delta_demo/loans_parquet/loans.parquet</td><td>loans.parquet</td><td>164631</td><td>1661645004000</td></tr></tbody></table></div>

# %%
# %sql 
-- REPEAT THE PREVIOUS STEP BUT USING SQL. CREATE A DELTA TABLE 
CREATE TABLE loans_delta2
USING DELTA AS
SELECT * FROM parquet.`file:/dbfs/tmp/delta_demo/loans_parquet`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Convert parquet files to Delta Lake format in place
CONVERT TO DELTA parquet.`file:/dbfs/tmp/delta_demo/loans_parquet`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %fs ls file:/dbfs/tmp/delta_demo/loans_parquet/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>file:/dbfs/tmp/delta_demo/loans_parquet/_delta_log/</td><td>_delta_log/</td><td>4096</td><td>1662334304167</td></tr><tr><td>file:/dbfs/tmp/delta_demo/loans_parquet/loans.parquet</td><td>loans.parquet</td><td>164631</td><td>1661645004000</td></tr></tbody></table></div>

# %%
spark.sql("SELECT COUNT(*) FROM loans_delta").show()
spark.sql("SELECT COUNT(*) FROM loans_delta2").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |   14705|
# +--------+
#
# +--------+
# |count(1)|
# +--------+
# |   14705|
# +--------+

# %%
# Set up 2 streaming writes to our table
stream_query_A = generate_and_append_data_stream(table_format="delta", table_name="loans_delta", schema_ok=True, type='stream A')
stream_query_B = generate_and_append_data_stream(table_format="delta", table_name="loans_delta", schema_ok=True, type='stream B')

# %%
# Streaming read #1
display(spark.readStream.format("delta").table("loans_delta").groupBy("type").count().orderBy("type"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>type</th><th>count</th></tr></thead><tbody><tr><td>batch</td><td>14705</td></tr><tr><td>stream A</td><td>417500</td></tr><tr><td>stream B</td><td>417000</td></tr></tbody></table></div>

# %%
# Streaming read #2
display(spark.readStream.format("delta").table("loans_delta").groupBy("type", window("timestamp", "10 seconds")).count().orderBy("window"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>type</th><th>window</th><th>count</th></tr></thead><tbody><tr><td>batch</td><td>List(2022-09-04T22:58:00.000+0000, 2022-09-04T22:58:10.000+0000)</td><td>14705</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:35:20.000+0000, 2022-09-04T23:35:30.000+0000)</td><td>2195</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:35:20.000+0000, 2022-09-04T23:35:30.000+0000)</td><td>1510</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:35:30.000+0000, 2022-09-04T23:35:40.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:35:30.000+0000, 2022-09-04T23:35:40.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:35:40.000+0000, 2022-09-04T23:35:50.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:35:40.000+0000, 2022-09-04T23:35:50.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:35:50.000+0000, 2022-09-04T23:36:00.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:35:50.000+0000, 2022-09-04T23:36:00.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:36:00.000+0000, 2022-09-04T23:36:10.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:36:00.000+0000, 2022-09-04T23:36:10.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:36:10.000+0000, 2022-09-04T23:36:20.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:36:10.000+0000, 2022-09-04T23:36:20.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:36:20.000+0000, 2022-09-04T23:36:30.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:36:20.000+0000, 2022-09-04T23:36:30.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:36:30.000+0000, 2022-09-04T23:36:40.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:36:30.000+0000, 2022-09-04T23:36:40.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:36:40.000+0000, 2022-09-04T23:36:50.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:36:40.000+0000, 2022-09-04T23:36:50.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:36:50.000+0000, 2022-09-04T23:37:00.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:36:50.000+0000, 2022-09-04T23:37:00.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:37:00.000+0000, 2022-09-04T23:37:10.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:37:00.000+0000, 2022-09-04T23:37:10.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:37:10.000+0000, 2022-09-04T23:37:20.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:37:10.000+0000, 2022-09-04T23:37:20.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:37:20.000+0000, 2022-09-04T23:37:30.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:37:20.000+0000, 2022-09-04T23:37:30.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:37:30.000+0000, 2022-09-04T23:37:40.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:37:30.000+0000, 2022-09-04T23:37:40.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:37:40.000+0000, 2022-09-04T23:37:50.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:37:40.000+0000, 2022-09-04T23:37:50.000+0000)</td><td>5000</td></tr><tr><td>stream B</td><td>List(2022-09-04T23:37:50.000+0000, 2022-09-04T23:38:00.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:37:50.000+0000, 2022-09-04T23:38:00.000+0000)</td><td>5000</td></tr><tr><td>stream A</td><td>List(2022-09-04T23:38:00.000+0000, 2022-09-04T23:38:10.000+0000)</td><td>5000</td></tr><tr><td>stream B< ...

# %%
spark.sql("SELECT COUNT(*) FROM loans_delta").show()
spark.sql("SELECT DISTINCT type FROM loans_delta LIMIT 10").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |  972205|
# +--------+
#
# +--------+
# |    type|
# +--------+
# |stream B|
# |stream A|
# |   batch|
# +--------+

# %%
# %sql
SELECT addr_state, COUNT(*)
FROM loans_delta
GROUP BY addr_state
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>addr_state</th><th>count(1)</th></tr></thead><tbody><tr><td>CA</td><td>37356</td></tr><tr><td>WA</td><td>35474</td></tr><tr><td>NY</td><td>36052</td></tr><tr><td>TX</td><td>36050</td></tr><tr><td>AZ</td><td>329</td></tr><tr><td>SC</td><td>174</td></tr><tr><td>LA</td><td>167</td></tr><tr><td>MN</td><td>256</td></tr><tr><td>NJ</td><td>541</td></tr><tr><td>DC</td><td>38</td></tr><tr><td>OR</td><td>178</td></tr><tr><td>VA</td><td>413</td></tr><tr><td>RI</td><td>66</td></tr><tr><td>WY</td><td>31</td></tr><tr><td>KY</td><td>157</td></tr><tr><td>NH</td><td>68</td></tr><tr><td>MI</td><td>366</td></tr><tr><td>NV</td><td>219</td></tr><tr><td>WI</td><td>202</td></tr><tr><td>ID</td><td>15</td></tr><tr><td>CT</td><td>216</td></tr><tr><td>NE</td><td>41</td></tr><tr><td>MT</td><td>28</td></tr><tr><td>NC</td><td>398</td></tr><tr><td>VT</td><td>32</td></tr><tr><td>MD</td><td>370</td></tr><tr><td>DE</td><td>31</td></tr><tr><td>MO</td><td>223</td></tr><tr><td>IL</td><td>578</td></tr><tr><td>ME</td><td>15</td></tr><tr><td>ND</td><td>20</td></tr><tr><td>MS</td><td>84</td></tr><tr><td>AL</td><td>183</td></tr><tr><td>IN</td><td>244</td></tr><tr><td>OH</td><td>504</td></tr><tr><td>TN</td><td>223</td></tr><tr><td>NM</td><td>68</td></tr><tr><td>PA</td><td>544</td></tr><tr><td>SD</td><td>31</td></tr><tr><td>WV</td><td>60</td></tr><tr><td>GA</td><td>495</td></tr><tr><td>MA</td><td>311</td></tr><tr><td>KS</td><td>118</td></tr><tr><td>FL</td><td>1005</td></tr><tr><td>CO</td><td>288</td></tr><tr><td>AK</td><td>35</td></tr><tr><td>AR</td><td>110</td></tr><tr><td>OK</td><td>146</td></tr><tr><td>UT</td><td>76</td></tr><tr><td>HI</td><td>76</td></tr></tbody></table></div>

# %%
dbutils.notebook.exit("stop")
# Out:
# stop

# %%
stop_all_streams()
# Out:
# Stopping all streams
# Stopped all streams

# %%
# %sql
--- VIEW THE DELTA LAKE TRANSACTION LOG
DESCRIBE HISTORY loans_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>50</td><td>2022-09-04T23:51:29.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 6746ce3c-2190-4aeb-8c65-464cbf17491f, epochId -> 24)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>48</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 18000, numOutputBytes -> 418341, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>49</td><td>2022-09-04T23:51:28.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 514bec85-90c1-4a91-95ac-4b678b6e0dce, epochId -> 24)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>48</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 17500, numOutputBytes -> 407680, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>48</td><td>2022-09-04T23:50:53.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 6746ce3c-2190-4aeb-8c65-464cbf17491f, epochId -> 23)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>46</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 26000, numOutputBytes -> 591851, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>47</td><td>2022-09-04T23:50:52.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 514bec85-90c1-4a91-95ac-4b678b6e0dce, epochId -> 23)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>46</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 26000, numOutputBytes -> 591824, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>46</td><td>2022-09-04T23:50:04.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 6746ce3c-2190-4aeb-8c65-464cbf17491f, epochId -> 22)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>44</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 18000, numOutputBytes -> 418410, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>45</td><td>2022-09-04T23:50:02.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 514bec85-90c1-4a91-95ac-4b678b6e0dce, epochId -> 22)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>44</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 17500, numOutputBytes -> 407688, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>44</td><td>2022-09-04T23:49:27.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 514bec85-90c1-4a91-95ac-4b678b6e0dce, epochId -> 21)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>42</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 27500, numOutputBytes -> 624219, numAdded ...

# %% [markdown]
# ##### Use schema enforcement to protect data quality

# %%
# Write dataframe with extra column, "credit_score", to Delta Lake table
new_column = [StructField("credit_score", IntegerType(), True)]

new_schema = StructType(spark.table("loans_delta").schema.fields + new_column)
data = [(99997, 10000, 1338.55, "CA", "batch", datetime.now(), 649),
        (99998, 20000, 1442.55, "NY", "batch", datetime.now(), 702)]

new_data = spark.createDataFrame(data, new_schema)
new_data.printSchema()
# Out:
# root
#  |-- loan_id: long (nullable = true)
#  |-- funded_amnt: integer (nullable = true)
#  |-- paid_amnt: double (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- credit_score: integer (nullable = true)

# %%
new_data.write.format("delta").mode("append").saveAsTable("loans_delta")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-2549487216592855> in <module>
# ----> 1 new_data.write.format("delta").mode("append").saveAsTable("loans_delta")
#
# /databricks/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#     804         if format is not None:
#     805             self.format(format)
# --> 806         self._jwrite.saveAsTable(name)
#     807
#     808     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: A schema mismatch detected when writing to the Delta table (Table ID: b9ff1150-ede9-45fa-91ba-9c311feef828).
# To enable schema migration using DataFrameWriter or DataStreamWriter, please set:
# '.option("mergeSchema", "true")'.
# For other operations, set the session configuration
# spark.databricks.delta.schema.autoMerge.enabled to "true". See the documentation
# specific to the operation for details.
#
# Table schema:
# root
# -- loan_id: long (nullable = true)
# -- funded_amnt: integer (nullable = true)
# -- paid_amnt: double (nullable = true)
# -- addr_state: string (nullable = true)
# -- type: string (nullable = true)
# -- timestamp: timestamp (nullable = true)
#
#
# Data schema:
# root
# -- loan_id: long (nullable = true)
# -- funded_amnt: integer (nullable = true)
# -- paid_amnt: double (nullable = true)
# -- addr_state: string (nullable = true)
# -- type: string (nullable = true)
# -- timestamp: timestamp (nullable = true)
# -- credit_score: integer (nullable = true)

# %% [markdown]
# ##### Use schema evolution to add new columns to schema

# %%
new_data.write.format("delta").mode("append").option("mergeSchema", "true").saveAsTable("loans_delta")

# %%
spark.table('loans_delta').printSchema()
# Out:
# root
#  |-- loan_id: long (nullable = true)
#  |-- funded_amnt: integer (nullable = true)
#  |-- paid_amnt: double (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- credit_score: integer (nullable = true)

# %%
# %sql
SELECT * FROM loans_delta
WHERE loan_id IN (99997, 99998);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>funded_amnt</th><th>paid_amnt</th><th>addr_state</th><th>type</th><th>timestamp</th><th>credit_score</th></tr></thead><tbody><tr><td>99997</td><td>6395</td><td>5068.754683799191</td><td>WA</td><td>stream A</td><td>2022-09-04T23:38:25.604+0000</td><td>null</td></tr><tr><td>99998</td><td>8493</td><td>7087.46838749574</td><td>WA</td><td>stream A</td><td>2022-09-04T23:38:25.606+0000</td><td>null</td></tr><tr><td>99997</td><td>7706</td><td>6004.825410352112</td><td>WA</td><td>stream B</td><td>2022-09-04T23:38:26.975+0000</td><td>null</td></tr><tr><td>99998</td><td>5080</td><td>4096.455744645483</td><td>NY</td><td>stream B</td><td>2022-09-04T23:38:26.977+0000</td><td>null</td></tr><tr><td>99997</td><td>10000</td><td>1338.55</td><td>CA</td><td>batch</td><td>2022-09-05T01:13:22.302+0000</td><td>649</td></tr><tr><td>99998</td><td>20000</td><td>1442.55</td><td>NY</td><td>batch</td><td>2022-09-05T01:13:22.302+0000</td><td>702</td></tr></tbody></table></div>

# %% [markdown]
# #### Delta Lake Time Travel
#
# Review Delta Lake table history for Auditing & Governance. You can query snapshots of your table by:
# 1. Version number
# 2. Timestamp

# %%
# %sql
DESCRIBE HISTORY loans_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>51</td><td>2022-09-05T01:14:29.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>50</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 2, numOutputBytes -> 2152)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>50</td><td>2022-09-04T23:51:29.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 6746ce3c-2190-4aeb-8c65-464cbf17491f, epochId -> 24)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>48</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 18000, numOutputBytes -> 418341, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>49</td><td>2022-09-04T23:51:28.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 514bec85-90c1-4a91-95ac-4b678b6e0dce, epochId -> 24)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>48</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 17500, numOutputBytes -> 407680, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>48</td><td>2022-09-04T23:50:53.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 6746ce3c-2190-4aeb-8c65-464cbf17491f, epochId -> 23)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>46</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 26000, numOutputBytes -> 591851, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>47</td><td>2022-09-04T23:50:52.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 514bec85-90c1-4a91-95ac-4b678b6e0dce, epochId -> 23)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>46</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 26000, numOutputBytes -> 591824, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>46</td><td>2022-09-04T23:50:04.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 6746ce3c-2190-4aeb-8c65-464cbf17491f, epochId -> 22)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>44</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 18000, numOutputBytes -> 418410, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>45</td><td>2022-09-04T23:50:02.000+0000</td><td>1057755597611259</td><td>matiasvargas598@gmail.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> 514bec85-90c1-4a91-95ac-4b678b6e0dce, epochId -> 22)</td><td>null</td><td>List(508300667251686)</td><td>0904-211633-11rrocdz</td><td>44</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 17500, numOutputBytes -> 407688, numAddedFiles -> 1)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>44</td><t ...

# %%
# COUNT OF ROWS OF THE VESION 0
spark.sql('SELECT COUNT(*) FirstVersionCount FROM loans_delta VERSION AS OF 0;').show()

# COUNT OF ROWS OF THE LAST VERSION
spark.sql('SELECT COUNT(*) LastVersionCount FROM loans_delta;').show()
# Out:
# +-----------------+
# |FirstVersionCount|
# +-----------------+
# |            14705|
# +-----------------+
#
# +----------------+
# |LastVersionCount|
# +----------------+
# |          972207|
# +----------------+

# %% [markdown]
# ##### Roll back a table to a specific version

# %%
# %sql
RESTORE loans_delta VERSION AS OF 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>165506</td><td>1</td><td>49</td><td>0</td><td>21993901</td><td>0</td></tr></tbody></table></div>

# %%
spark.sql('SELECT COUNT(*) LastVersionCount FROM loans_delta;').show()
# Out:
# +----------------+
# |LastVersionCount|
# +----------------+
# |           14705|
# +----------------+

# %% [markdown]
# ### DML Support
# Parquet does not support these commands - they are unique to Delta Lake

# %%
# %sql
SELECT * FROM loans_delta WHERE loan_id=4420
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>funded_amnt</th><th>paid_amnt</th><th>addr_state</th><th>type</th><th>timestamp</th></tr></thead><tbody><tr><td>4420</td><td>22000</td><td>1050.94</td><td>TX</td><td>batch</td><td>2022-09-04T22:58:08.108+0000</td></tr></tbody></table></div>

# %%
# %sql
--DELETE COMMAND
DELETE FROM loans_delta WHERE loan_id=4420;
-- Confirm the user's data was deleted
SELECT * FROM loans_delta WHERE loan_id=4420
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>funded_amnt</th><th>paid_amnt</th><th>addr_state</th><th>type</th><th>timestamp</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
--INSERT COMMAND
INSERT INTO loans_delta
SELECT * FROM loans_delta VERSION AS OF 0
WHERE loan_id=4420;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
-- Confirm the user's data was inserted
SELECT * FROM loans_delta WHERE loan_id=4420
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>funded_amnt</th><th>paid_amnt</th><th>addr_state</th><th>type</th><th>timestamp</th></tr></thead><tbody><tr><td>4420</td><td>22000</td><td>1050.94</td><td>TX</td><td>batch</td><td>2022-09-04T22:58:08.108+0000</td></tr></tbody></table></div>

# %%
# %sql
UPDATE loans_delta SET funded_amnt = 50000 WHERE loan_id = 4420;
-- Confirm the user's data was updated
SELECT * FROM loans_delta WHERE loan_id = 4420;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>funded_amnt</th><th>paid_amnt</th><th>addr_state</th><th>type</th><th>timestamp</th></tr></thead><tbody><tr><td>4420</td><td>50000</td><td>1050.94</td><td>TX</td><td>batch</td><td>2022-09-04T22:58:08.108+0000</td></tr></tbody></table></div>

# %% [markdown]
# ###### Support Change Data Capture Workflows & Other Ingest Use Cases via MERGE INTO

# %%
# Create merge table with 1 row update, 1 insertion
data = [(4420, 22000, 21500.00, "NY", "update", datetime.now()),  # record to update
        (99999, 10000, 1338.55, "CA", "insert", datetime.now())]  # record to insert

schema = spark.table("loans_delta").schema

spark.createDataFrame(data, schema).createOrReplaceTempView("merge_table")

spark.sql("SELECT * FROM merge_table").show()
# Out:
# +-------+-----------+---------+----------+------+--------------------+
# |loan_id|funded_amnt|paid_amnt|addr_state|  type|           timestamp|
# +-------+-----------+---------+----------+------+--------------------+
# |   4420|      22000|  21500.0|        NY|update|2022-09-05 01:45:...|
# |  99999|      10000|  1338.55|        CA|insert|2022-09-05 01:45:...|
# +-------+-----------+---------+----------+------+--------------------+

# %%
# %sql
MERGE INTO loans_delta AS l
USING merge_table AS m
ON l.loan_id = m.loan_id
WHEN MATCHED THEN 
  UPDATE SET *
WHEN NOT MATCHED 
  THEN INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>1</td><td>0</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM loans_delta WHERE loan_id IN (4420, 99999)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>funded_amnt</th><th>paid_amnt</th><th>addr_state</th><th>type</th><th>timestamp</th></tr></thead><tbody><tr><td>4420</td><td>22000</td><td>21500.0</td><td>NY</td><td>update</td><td>2022-09-05T01:45:27.986+0000</td></tr><tr><td>99999</td><td>10000</td><td>1338.55</td><td>CA</td><td>insert</td><td>2022-09-05T01:45:27.986+0000</td></tr></tbody></table></div>

# %% [markdown]
# #### File compaction and performance optimizations = faster queries

# %% [markdown]
# ###### Vacuum

# %%
# %sql
-- Vacuum deletes all files no longer needed by the current version of the table.
VACUUM loans_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/deltadb.db/loans_delta</td></tr></tbody></table></div>

# %% [markdown]
# ###### Cache table in memory (Databricks Delta Lake only) to speed up that query in the future

# %%
# %sql
CACHE SELECT * FROM loans_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ###### Z-Order Optimize (Databricks Delta Lake only)

# %%
# %sql
OPTIMIZE loans_delta ZORDER BY addr_state;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/deltadb.db/loans_delta</td><td>List(1, 2, List(165524, 165524, 165524.0, 1, 165524), List(1868, 165507, 83687.5, 2, 167375), 0, List(minCubeSize(107374182400), List(0, 0), List(2, 167375), 0, List(2, 167375), 1, null), 1, 2, 0, false)</td></tr></tbody></table></div>

# %%
cleanup_paths_and_tables()
